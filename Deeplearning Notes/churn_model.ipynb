# %%
import pandas as pd  
import numpy as np 
import tensorflow as tf
# Out:
# WARNING:tensorflow:From c:\Users\aka90\Desktop\abhi vs code\Deep_learning\Dlenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv(r"C:\Users\aka90\Desktop\classroom pdf\PYTHON NOTES\AUGUST\1st, 2nd, 4th- ENSAMBLE LEARNING\CHURN MODELING- TF\Churn_Modelling.csv")
