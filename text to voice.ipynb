# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('''Good [morning/afternoon/evening], everyone!

It gives me great pleasure to welcome you all to this special occasion. Whether you are joining us in person or virtually, thank you for being here today. Your presence is what makes this gathering meaningful.

We are honored to have among us distinguished guests, respected colleagues, enthusiastic participants, and dedicated organizers. Today marks an important moment—an opportunity to share ideas, celebrate achievements, and build lasting connections.

This event wouldn’t be possible without the hard work of a committed team. A heartfelt thank you to everyone who worked behind the scenes to bring it all together. Your efforts are truly appreciated.

As we move forward with our program, I encourage each of you to engage fully—ask questions, participate in discussions, and most importantly, enjoy the experience. Let this be a day of inspiration, learning, and collaboration.

Once again, welcome, and thank you for being part of this event. Let’s make it a memorable one!''',lang='hi',tld='com')

text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay= False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS

# %%
from gtts import gTTS
import os

# Text to convert
text = "Hello, how are you?"

# Language in which you want to convert
language = 'en'

# Passing the text and language to the engine
speech = gTTS(text=text, lang=language, slow=False)

# Saving the converted audio in a mp3 file
speech.save("output.mp3")

# Playing the converted file (optional)
os.system("start output.mp3")  # On Windows
# os.system("afplay output.mp3")  # On macOS
# os.system("mpg123 output.mp3")  # On Linux
# Out:
# 0

# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
import os

# Text to convert
text = "Hello, how are you?"

# Language in which you want to convert
language = 'en'

# Passing the text and language to the engine
speech = gTTS(text=text, lang=language, slow=False)

# Saving the converted audio in a mp3 file
speech.save("output.mp3")

# Playing the converted file (optional)
os.system("start output.mp3")  # On Windows
# os.system("afplay output.mp3")  # On macOS
# os.system("mpg123 output.mp3")  # On Linux
# Out:
# 0

# %%
from gtts import gTTS
from IPython.display import Audio

# Hindi text written in Devanagari script
hindi_text = '''नरेश टेक्नोलॉजी डाटा साइंस प्रोग्राम में आपका स्वागत है, 
जो प्रकाश सेनापति के मार्गदर्शन में चलाया जा रहा है। 
यह क्लासेज़ प्रैक्टिकल एक्सपोज़र देने में मदद करती हैं 
ताकि आपकी तकनीकी कौशल में बढ़ोतरी हो सके और 
कोडिंग स्किल्स बेहतर हो सकें। 
हम यह प्रोग्राम तकनीकी और गैर-तकनीकी दोनों तरह के शिक्षार्थियों के लिए आयोजित करते हैं। धन्यवाद।'''

text_to_speech = gTTS(hindi_text, lang='hi', tld='com')

text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

# Play the audio
Audio(sound_file, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('''welcome to naresh technology data science programme under prakash senapati guidance. 
                        classes will help practicle exposure to boost up technical skill 
                        and increase learning for coding skills. we conduct this programme for 
                        both non-technical and technical learners. Thank you.''',lang='hi',tld='com')
text_to_speech = gTTS(hindi_text, lang='hi', tld='com')
text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay= False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for v in voice:
    print(v.id,v.name,v.languages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 for v in voice:
#       2     print(v.id,v.name,v.languages)
#
# NameError: name 'voice' is not defined

# %%
pip install voice
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.3 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.3 MB 6.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.7/8.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 8.7 MB/s eta 0:00:00
# ...
#   Created wheel for voice: filename=Voice-0.1.0-py3-none-any.whl size=9344 sha256=3c9ec86bec28ab4f0a156d22a49cae60c5e84d6dca9da3e88a5264c3e52dca5c
#   Stored in directory: c:\users\aka90\appdata\local\pip\cache\wheels\e4\47\20\7b95c316029c1ba56a29ffed4157e114c00add4822dc8df583
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

text_to_speech = gTTS('''welcome to naresh technology data science programme under prakash senapati guidance. 
                        classes will help practicle exposure to boost up technical skill 
                        and increase learning for coding skills. we conduct this programme for 
                        both non-technical and technical learners. Thank you.''',lang='en',tld='co.in')
text_to_speech = gTTS(hindi_text, lang='hi', tld='co.in')
text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       2 from IPython.display import Audio
#       4 text_to_speech = gTTS('''welcome to naresh technology data science programme under prakash senapati guidance.
#       5                         classes will help practicle exposure to boost up technical skill
#       6                         and increase learning for coding skills. we conduct this programme for
#       7                         both non-technical and technical learners. Thank you.''',lang='en',tld='co.in')
# ----> 8 text_to_speech = gTTS(hindi_text, lang='hi', tld='co.in')
#       9 text_to_speech.save('text_to_speech_gtts.wav')
#      10 sound_file = 'text_to_speech_gtts.wav'
#
# NameError: name 'hindi_text' is not defined

# %%
from gtts import gTTS
from IPython.display import Audio

hindi_text = gTTS('''welcome to naresh technology data science programme under prakash senapati guidance. 
                        classes will help practicle exposure to boost up technical skill
                        and increase learning for coding skills. we conduct this programme for 
                        both non-technical and technical learners. Thank you.''',lang='hi',tld='co.in')
text_to_speech = gTTS(hindi_text, lang='te', tld='co.in')
text_to_speech.save('text_to_speech_gtts.wav')
sound_file = 'text_to_speech_gtts.wav'

Audio(sound_file, autoplay= False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\aka90\anaconda3\Lib\site-packages\gtts\tts.py:316, in gTTS.write_to_fp(self, fp)
#     315 try:
# --> 316     for idx, decoded in enumerate(self.stream()):
#     317         fp.write(decoded)
#
# File c:\Users\aka90\anaconda3\Lib\site-packages\gtts\tts.py:263, in gTTS.stream(self)
#     261     pass
# --> 263 prepared_requests = self._prepare_requests()
#     264 for idx, pr in enumerate(prepared_requests):
#
# File c:\Users\aka90\anaconda3\Lib\site-packages\gtts\tts.py:207, in gTTS._prepare_requests(self)
#     203 translate_url = _translate_url(
#     204     tld=self.tld, path="_/TranslateWebserverUi/data/batchexecute"
#     205 )
# --> 207 text_parts = self._tokenize(self.text)
#     208 log.debug("text_parts: %s", str(text_parts))
#
# ...

# %%
for v in voi

# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3

engine = pyttsx3.init()
voices = engine.getProperty('voices')

for v in voices:
    print(f"ID: {v.id}, Name: {v.name}, Languages: {v.languages}")
# Out:
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_DAVID_11.0, Name: Microsoft David Desktop - English (United States), Languages: ['en-US']
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0, Name: Microsoft Zira Desktop - English (United States), Languages: ['en-US']
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_ZH-CN_HUIHUI_11.0, Name: Microsoft Huihui Desktop - Chinese (Simplified), Languages: ['zh-CN']
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_ZH-TW_HANHAN_11.0, Name: Microsoft Hanhan Desktop - Chinese (Taiwan), Languages: ['zh-TW']

# %%
for v in voice:
    print(v.id, v.name, v.languages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for v in voice:
#       2     print(v.id, v.name, v.languages)
#
# NameError: name 'voice' is not defined

# %%
pip install bhawana
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement bhawana (from versions: none)
# ERROR: No matching distribution found for bhawana
