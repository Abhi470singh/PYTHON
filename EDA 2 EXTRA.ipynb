# %% [markdown]
# # EDA PRACTICE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
heart_data=pd.read_csv(r"C:\Users\aka90\Downloads\heart.csv")

# %%
heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
print('Thebshape of the dataset : ', heart_data.shape)
# Out:
# Thebshape of the dataset :  (303, 14)

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_data['target'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64>

# %%
heart_data['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f , ax = plt.subplots(figsize=(8,6))
ax = sns.countplot(x="target",data=heart_data)
plt.show()

# %%
heart_data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="sex", hue="target", data=heart_data)
plt.show()

# %%
ax = sns.catplot(x="target", col="sex", data=heart_data, kind="count", height=5, aspect=1)

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(y="target", hue="sex", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=heart_data, palette="Set3")
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", data=heart_data, facecolor=(0, 0, 0, 0), linewidth=5, edgecolor=sns.color_palette("dark", 3))
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="fbs", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="target", hue="exang", data=heart_data)
plt.show()

# %%
correlation = heart_data.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
heart_data['cp'].nunique()
# Out:
# 4

# %%
heart_data['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="cp", data=heart_data)
plt.show()

# %%
heart_data.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.countplot(x="cp", hue="target", data=heart_data)
plt.show()

# %%
ax = sns.catplot(x="target", col="cp", data=heart_data, kind="count", height=8, aspect=1)

# %%
heart_data['thalach'].nunique()
# Out:
# 91

# %%
heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
ax = sns.distplot(x, bins=10, vertical=True)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x)
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='r')
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='g')
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='r')
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='w')
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
x = pd.Series(x, name="thalach variable")
ax = sns.kdeplot(x, shade=True, color='b')
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['thalach']
ax = sns.distplot(x, kde=False, rug=True, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="thalach", data=heart_data, jitter = 0.01)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="thalach", data=heart_data)
plt.show()

# %%
plt.figure(figsize=(16,12))
plt.title('Correlation Heatmap of Heart Disease Dataset')
a = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
a.set_xticklabels(a.get_xticklabels(), rotation=90)
a.set_yticklabels(a.get_yticklabels(), rotation=30)           
plt.show()

# %%
num_var = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target' ]
sns.pairplot(heart_data[num_var], kind='scatter', diag_kind='hist')
plt.show()

# %%
heart_data['age'].nunique()
# Out:
# 41

# %%
heart_data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(10,6))
x = heart_data['age']
ax = sns.distplot(x, bins=10)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="target", y="age", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x="target", y="age", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="trestbps", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="trestbps", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="age", y="chol", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="age", y="chol", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.scatterplot(x="chol", y = "thalach", data=heart_data)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.regplot(x="chol", y="thalach", data=heart_data)
plt.show()

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
assert pd.notnull(heart_data).all().all()

# %%
assert (heart_data>=0).all().all()

# %%
heart_data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=heart_data["age"])
plt.show()

# %%
heart_data['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=heart_data["trestbps"])
plt.show()

# %%
heart_data['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=heart_data["chol"])
plt.show()

# %%
heart_data['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=heart_data["thalach"])
plt.show()

# %%
heart_data['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.boxplot(x=heart_data["oldpeak"])
plt.show()
